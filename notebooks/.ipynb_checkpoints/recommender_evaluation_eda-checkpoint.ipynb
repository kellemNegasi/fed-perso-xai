# %% [markdown]
# # Recommender Held-Out Evaluation Report
#
# This notebook loads the final recommender evaluation for a single `run_id` and summarizes the **held-out test split**.
#
# It is designed for the new recommender flow where:
# - train/test are split by `dataset_index`
# - final metrics come from the saved `evaluation_summary.json`
# - missing recommender artifacts raise a clear error instead of silently falling back

# %%
from __future__ import annotations

import json
import math
import re
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import HTML, display

plt.style.use("seaborn-v0_8-whitegrid")
pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 200)
pd.set_option("display.max_colwidth", 120)

# %%
QUANTIZATION_HISTORY_METRIC = globals().get("COMPARISON_METRIC", "precision_at_5")
QUANTIZATION_HISTORY_GLOB = "recommender_evaluation_comparison_outputs_*"
if "REPO_ROOT" in globals():
    QUANTIZATION_HISTORY_REPO_ROOT = Path(REPO_ROOT)
else:
    _history_current = Path.cwd().resolve()
    QUANTIZATION_HISTORY_REPO_ROOT = next(
        (
            candidate
            for candidate in [_history_current, *_history_current.parents]
            if (candidate / "pyproject.toml").exists()
        ),
        _history_current,
    )
QUANTIZATION_HISTORY_SELECTION_ID = globals().get("SELECTION_ID", "test__max-20__seed-42")
QUANTIZATION_HISTORY_PERSONA = globals().get("PERSONA", "lay")


def _history_load_json(path: Path) -> dict:
    return json.loads(path.read_text(encoding="utf-8"))


def _history_sanitize_segment(value: object) -> str:
    text = str(value).strip()
    cleaned = [char if (char.isalnum() or char in "._-") else "_" for char in text]
    normalized = "".join(cleaned).strip("._")
    return normalized or "value"


def _history_save_dataframe(frame: pd.DataFrame, output_dir: Path, stem: str, *, index: bool = False) -> dict[str, str]:
    output_dir.mkdir(parents=True, exist_ok=True)
    csv_path = output_dir / f"{stem}.csv"
    html_path = output_dir / f"{stem}.html"
    frame.to_csv(csv_path, index=index)
    frame.to_html(html_path, index=index)
    return {"csv": str(csv_path), "html": str(html_path)}


def _history_save_figure(fig: plt.Figure, output_dir: Path, stem: str, *, dpi: int = 200) -> str:
    output_dir.mkdir(parents=True, exist_ok=True)
    path = output_dir / f"{stem}.png"
    fig.savefig(path, dpi=dpi, bbox_inches="tight")
    return str(path)


def _history_save_json(path: Path, payload: dict) -> Path:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2), encoding="utf-8")
    return path


def _scale_from_suffix(scale_suffix: str) -> int | None:
    match = re.fullmatch(r"2e(\d+)", str(scale_suffix).strip())
    if not match:
        return None
    return 1 << int(match.group(1))


def _load_quantization_history(metric: str) -> pd.DataFrame:
    rows: list[dict[str, object]] = []
    comparison_roots = sorted((QUANTIZATION_HISTORY_REPO_ROOT / "notebooks").glob(QUANTIZATION_HISTORY_GLOB))
    for comparison_root in comparison_roots:
        manifest_path = (
            comparison_root
            / _history_sanitize_segment(QUANTIZATION_HISTORY_SELECTION_ID)
            / _history_sanitize_segment(QUANTIZATION_HISTORY_PERSONA)
            / _history_sanitize_segment(metric)
            / "comparison_export_manifest.json"
        )
        if not manifest_path.exists():
            continue
        manifest = _history_load_json(manifest_path)
        scale_suffix = comparison_root.name.replace("recommender_evaluation_comparison_outputs_", "", 1)
        scale_value = manifest.get("secure_quantization_scale")
        if scale_value is None:
            scale_value = _scale_from_suffix(scale_suffix)
        try:
            scale_value = int(scale_value) if scale_value is not None else None
        except (TypeError, ValueError):
            scale_value = None
        for summary_path in sorted(manifest_path.parent.glob("run_id*_summary_*.csv")):
            summary_frame = pd.read_csv(summary_path)
            if summary_frame.empty:
                continue
            secure_rows = summary_frame.loc[summary_frame["aggregation_mode"] == "secure"]
            plain_rows = summary_frame.loc[summary_frame["aggregation_mode"] == "plain"]
            if secure_rows.empty or plain_rows.empty:
                continue
            secure_row = secure_rows.iloc[0]
            plain_row = plain_rows.iloc[0]
            run_alias = summary_path.name.split("_summary_", 1)[0]
            diagnostics_path = manifest_path.parent / f"{run_alias}_diagnostics.json"
            diagnostics = _history_load_json(diagnostics_path) if diagnostics_path.exists() else {}
            rows.append(
                {
                    "scale_suffix": scale_suffix,
                    "secure_quantization_scale": scale_value,
                    "run_alias": run_alias,
                    "run_id": diagnostics.get("run_id"),
                    "precision_at_5_plain": float(plain_row.get("aggregate", np.nan)),
                    "precision_at_5_secure": float(secure_row.get("aggregate", np.nan)),
                    "precision_at_5_delta": float(secure_row.get("aggregate", np.nan) - plain_row.get("aggregate", np.nan)),
                    "pearson_plain": float(diagnostics.get("pearson_plain", np.nan)),
                    "pearson_secure": float(diagnostics.get("pearson_secure", np.nan)),
                    "pearson_delta": float(diagnostics.get("pearson_delta", np.nan)),
                    "max_abs_error_max": float(diagnostics.get("max_abs_error_max", np.nan)),
                    "max_abs_error_mean": float(diagnostics.get("max_abs_error_mean", np.nan)),
                    "model_l2_diff": float(diagnostics.get("model_l2_diff", np.nan)),
                    "model_max_abs_diff": float(diagnostics.get("model_max_abs_diff", np.nan)),
                    "diagnostics_available": bool(diagnostics),
                }
            )
    if not rows:
        raise ValueError(
            "No quantization-history comparison folders were found for the current selection/persona/metric."
        )
    frame = pd.DataFrame(rows)
    return frame.sort_values(["secure_quantization_scale", "run_alias"]).reset_index(drop=True)


quantization_history = _load_quantization_history(QUANTIZATION_HISTORY_METRIC)
QUANTIZATION_HISTORY_OUTPUT_DIR = (
    QUANTIZATION_HISTORY_REPO_ROOT
    / "notebooks"
    / "recommender_evaluation_quantization_history"
    / _history_sanitize_segment(QUANTIZATION_HISTORY_SELECTION_ID)
    / _history_sanitize_segment(QUANTIZATION_HISTORY_PERSONA)
    / _history_sanitize_segment(QUANTIZATION_HISTORY_METRIC)
)
QUANTIZATION_HISTORY_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
quantization_history_display = quantization_history[
    [
        "scale_suffix",
        "secure_quantization_scale",
        "run_alias",
        "precision_at_5_delta",
        "pearson_delta",
        "max_abs_error_max",
        "max_abs_error_mean",
        "model_l2_diff",
        "model_max_abs_diff",
        "diagnostics_available",
    ]
].copy()
quantization_history_display["log2_scale"] = quantization_history_display["secure_quantization_scale"].map(
    lambda value: int(math.log2(value)) if pd.notna(value) and float(value) > 0 else np.nan
)
quantization_history_table_paths = _history_save_dataframe(
    quantization_history_display,
    QUANTIZATION_HISTORY_OUTPUT_DIR,
    "quantization_history",
)
if "NOTEBOOK_EXPORT_MANIFEST" in globals() and "OUTPUT_DIR" in globals():
    NOTEBOOK_EXPORT_MANIFEST["saved_tables"]["quantization_history"] = quantization_history_table_paths
    _history_save_json(Path(OUTPUT_DIR) / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)
quantization_history_display

if not bool(quantization_history["diagnostics_available"].all()):
    display(
        HTML(
            "<div style='padding:10px 12px;border:1px solid #f0c36d;border-radius:10px;background:#fff8e1'>"
            "Historical comparison folders without per-scale diagnostics only contribute <code>precision_at_5</code>. "
            "Pearson, secure max_abs_error, and model-difference trends appear only for scales where diagnostics snapshots were saved."
            "</div>"
        )
    )

fig, axes = plt.subplots(2, 2, figsize=(18, 10), sharex=True)
plot_specs = [
    ("precision_at_5_delta", "Precision@5 Delta (secure - plain)", False),
    ("pearson_delta", "Pearson Delta (secure - plain)", False),
    ("max_abs_error_max", "Secure Aggregation Max Abs Error", True),
    ("model_l2_diff", "Model L2 Difference", True),
]
run_aliases = sorted(quantization_history["run_alias"].unique())
color_map = {
    run_alias: color
    for run_alias, color in zip(
        run_aliases,
        ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"],
    )
}
for axis, (column, title, use_log_scale) in zip(axes.flat, plot_specs, strict=True):
    for run_alias in run_aliases:
        run_frame = quantization_history.loc[quantization_history["run_alias"] == run_alias].sort_values(
            "secure_quantization_scale"
        )
        axis.plot(
            run_frame["secure_quantization_scale"],
            run_frame[column],
            marker="o",
            linewidth=2,
            label=run_alias,
            color=color_map.get(run_alias),
        )
    if use_log_scale and pd.to_numeric(quantization_history[column], errors="coerce").dropna().gt(0).any():
        axis.set_yscale("log")
    axis.set_xscale("log", base=2)
    axis.set_title(title)
    axis.set_xlabel("secure_quantization_scale")
    axis.grid(True, which="both", alpha=0.3)

axes[0, 0].set_ylabel("delta")
axes[0, 1].set_ylabel("delta")
axes[1, 0].set_ylabel("max abs error")
axes[1, 1].set_ylabel("L2 difference")
axes[0, 0].legend(title="run_alias", loc="best")
plt.tight_layout()
quantization_history_figure_path = _history_save_figure(
    fig,
    QUANTIZATION_HISTORY_OUTPUT_DIR,
    "quantization_history_trends",
)
if "NOTEBOOK_EXPORT_MANIFEST" in globals() and "OUTPUT_DIR" in globals():
    NOTEBOOK_EXPORT_MANIFEST["saved_figures"]["quantization_history_trends"] = quantization_history_figure_path
    _history_save_json(Path(OUTPUT_DIR) / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)
plt.show()

quantization_history_pivot = quantization_history.pivot_table(
    index="scale_suffix",
    columns="run_alias",
    values=["precision_at_5_delta", "pearson_delta", "max_abs_error_max", "model_l2_diff"],
)
quantization_history_pivot
# Out:
# <div style='padding:10px 12px;border:1px solid #f0c36d;border-radius:10px;background:#fff8e1'>Historical comparison folders without per-scale diagnostics only contribute <code>precision_at_5</code>. Pearson, secure max_abs_error, and model-difference trends appear only for scales where diagnostics snapshots were saved.</div>
#              max_abs_error_max                             model_l2_diff                   pearson_delta                     precision_at_5_delta
# run_alias              run_id1       run_id2       run_id3       run_id1 run_id2   run_id3       run_id1   run_id2   run_id3              run_id1 run_id2   run_id3
# scale_suffix
# 2e16                       NaN           NaN           NaN           NaN     NaN       NaN           NaN       NaN       NaN            -0.009700  0.0033 -0.001402
# 2e20                       NaN           NaN           NaN           NaN     NaN       NaN           NaN       NaN       NaN            -0.009700  0.0033 -0.011536
# ...

# %%
# Edit these values to inspect another recommender run.
# RUN_ID = "federated-training-adult_income-20260426t223642651433+0000-logistic_regression-10clients-alpha0.3-seed42-e8df09baaba3"
# RUN_ID = "federated-training-adult_income-20260425t192946577949+0000-logistic_regression-10clients-alpha1.0-seed42-dba03a50b07b"
RUN_ID = "federated-training-adult_income-20260427t063710289874+0000-logistic_regression-15clients-alpha0.3-seed42-536f2cd41ed2"
SELECTION_ID = "test__max-20__seed-42"
PERSONA = "lay"
RECOMMENDER_MODEL_KEY = "svm_rank_fedavg"
AGGREGATION_MODE_OVERRIDE = "secure"

# %%
def find_repo_root(start: Path | None = None) -> Path:
    current = (start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "pyproject.toml").exists():
            return candidate
    raise FileNotFoundError("Could not locate repo root containing pyproject.toml")


def load_json(path: Path) -> dict:
    return json.loads(path.read_text(encoding="utf-8"))


def parse_run_id(run_id: str) -> dict[str, object]:
    info: dict[str, object] = {"run_id": run_id}
    match = re.search(
        r"federated-training-(?P<dataset>.+?)-(?P<timestamp>\d{8}t\d{6}\d+\+\d+)-(?P<model>.+?)-(?P<num_clients>\d+)clients-alpha(?P<alpha>[^-]+)-seed(?P<seed>\d+)",
        run_id,
    )
    if not match:
        return info
    info.update(match.groupdict())
    info["num_clients"] = int(info["num_clients"])
    info["seed"] = int(info["seed"])
    try:
        info["alpha"] = float(info["alpha"])
    except ValueError:
        pass
    return info


def _legacy_train_dir(
    repo_root: Path,
    run_id: str,
    selection_id: str,
    persona: str,
    model_key: str,
) -> Path:
    return (
        repo_root
        / "federated"
        / "runs"
        / run_id
        / "recommender_training"
        / selection_id
        / persona
        / model_key
    )


def _legacy_train_dir_secure_aggregation(train_dir: Path) -> bool | None:
    metadata_path = train_dir / "training_metadata.json"
    if not metadata_path.exists():
        return None
    try:
        payload = load_json(metadata_path)
    except (OSError, json.JSONDecodeError):
        return None
    config = payload.get("config")
    if not isinstance(config, dict):
        return None
    raw_value = config.get("secure_aggregation")
    if raw_value is None:
        return None
    return bool(raw_value)


def resolve_train_dir(
    repo_root: Path,
    run_id: str,
    selection_id: str,
    persona: str,
    model_key: str,
    aggregation_mode: str | None = None,
) -> Path:
    base_dir = _legacy_train_dir(repo_root, run_id, selection_id, persona, model_key)
    plain_dir = base_dir / "plain"
    secure_dir = base_dir / "secure"
    if aggregation_mode is not None:
        normalized_mode = str(aggregation_mode).strip().lower()
        if normalized_mode not in {"plain", "secure"}:
            raise ValueError("aggregation_mode must be one of {'plain', 'secure'} when provided.")
        preferred_dir = plain_dir if normalized_mode == "plain" else secure_dir
        if preferred_dir.exists():
            return preferred_dir
        legacy_secure_aggregation = _legacy_train_dir_secure_aggregation(base_dir)
        if base_dir.exists() and (
            legacy_secure_aggregation == (normalized_mode == "secure")
            or (legacy_secure_aggregation is None and normalized_mode == "plain")
        ):
            return base_dir
        return preferred_dir
    existing_mode_dirs = [path for path in (plain_dir, secure_dir) if path.exists()]
    if len(existing_mode_dirs) == 1:
        return existing_mode_dirs[0]
    if len(existing_mode_dirs) > 1:
        raise FileExistsError(
            f"Run {run_id!r} has both plain and secure recommender artifacts. "
            "Set AGGREGATION_MODE_OVERRIDE to choose one explicitly."
        )
    return base_dir


def require_recommender_artifacts(train_dir: Path, run_id: str) -> dict[str, Path]:
    paths = {
        "evaluation_summary": train_dir / "evaluation_summary.json",
        "training_metadata": train_dir / "training_metadata.json",
        "model_artifact": train_dir / "model" / "global_recommender.npz",
    }
    missing = [name for name, path in paths.items() if not path.exists()]
    if missing:
        missing_text = ", ".join(missing)
        raise FileNotFoundError(
            f"Run {run_id!r} does not have completed recommender artifacts in {train_dir}. Missing: {missing_text}."
        )
    return paths


def format_value(value: object) -> str:
    if value is None:
        return "n/a"
    if isinstance(value, float):
        if math.isnan(value):
            return "n/a"
        return f"{value:.4f}"
    if isinstance(value, (list, tuple)):
        return ", ".join(str(item) for item in value)
    return str(value)


def make_metric_card(title: str, value: object, subtitle: str = "") -> str:
    subtitle_html = f"<div style='font-size:12px;color:#5f6368'>{subtitle}</div>" if subtitle else ""
    return (
        "<div style='padding:14px 16px;border:1px solid #d0d7de;border-radius:12px;"
        "background:#f8fafc;min-width:180px'>"
        f"<div style='font-size:12px;text-transform:uppercase;color:#5f6368;letter-spacing:0.04em'>{title}</div>"
        f"<div style='font-size:26px;font-weight:700;margin-top:4px'>{format_value(value)}</div>"
        f"{subtitle_html}"
        "</div>"
    )


def build_title_block(run_info: dict[str, object], training_metadata: dict, selection_id: str, persona: str) -> HTML:
    config = training_metadata.get("config", {})
    cards = [
        make_metric_card("Aggregation", "Secure" if config.get("secure_aggregation") else "Plain"),
        make_metric_card("Rounds", config.get("rounds")),
        make_metric_card("Clients", training_metadata.get("num_clients")),
        make_metric_card("Top-K", training_metadata.get("top_k")),
    ]
    title_html = (
        f"<h2 style='margin-bottom:4px'>Recommender evaluation: {run_info.get('dataset', 'unknown dataset')}</h2>"
        f"<div style='color:#5f6368;margin-bottom:14px'><code>{run_info.get('run_id')}</code></div>"
        f"<div style='display:flex;gap:12px;flex-wrap:wrap'>{''.join(cards)}</div>"
        f"<div style='margin-top:12px;color:#5f6368'>selection_id=<code>{selection_id}</code> | persona=<code>{persona}</code></div>"
    )
    return HTML(title_html)


def summarize_metric(frame: pd.DataFrame, metric: str) -> dict[str, object]:
    values = pd.to_numeric(frame[metric], errors="coerce")
    return {
        "metric": metric,
        "mean": float(values.mean()),
        "std": float(values.std(ddof=0)),
        "min": float(values.min()),
        "max": float(values.max()),
    }


def build_client_metrics_frame(evaluation_summary: dict) -> pd.DataFrame:
    client_rows = []
    for client_entry in evaluation_summary.get("clients", []):
        row = {
            "client_id": client_entry.get("client_id"),
            "instance_count": client_entry.get("instance_count", client_entry.get("test_instance_count")),
            "candidate_count": client_entry.get("candidate_count"),
            "pair_count": client_entry.get("pair_count"),
        }
        nested_metrics = client_entry.get("metrics")
        if isinstance(nested_metrics, dict):
            for metric_name, metric_value in nested_metrics.items():
                row[metric_name] = metric_value
        for key, value in client_entry.items():
            if key in {"client_id", "instance_count", "test_instance_count", "candidate_count", "pair_count", "instances", "metrics"}:
                continue
            if isinstance(key, str) and (key == "pearson" or key.startswith("precision_at_") or key.startswith("pearson_at_")):
                row[key] = value
        client_rows.append(row)
    frame = pd.DataFrame(client_rows)
    if not frame.empty and "client_id" in frame.columns:
        frame = frame.sort_values("client_id").reset_index(drop=True)
    return frame


def build_aggregate_metric_summary(frame: pd.DataFrame) -> pd.DataFrame:
    metric_columns = [
        column
        for column in frame.columns
        if column not in {"client_id", "test_instance_count", "pair_count"}
        and pd.api.types.is_numeric_dtype(frame[column])
    ]
    return pd.DataFrame([summarize_metric(frame, metric) for metric in metric_columns])


def save_json(path: Path, payload: dict) -> Path:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2), encoding="utf-8")
    return path


def sanitize_segment(value: object) -> str:
    text = str(value).strip()
    cleaned = [char if (char.isalnum() or char in "._-") else "_" for char in text]
    normalized = "".join(cleaned).strip("._")
    return normalized or "value"


def aggregation_mode_label(training_metadata: dict) -> str:
    config = training_metadata.get("config", {})
    return "secure" if bool(config.get("secure_aggregation")) else "plain"


def safe_metric_columns(frame: pd.DataFrame) -> list[str]:
    metric_columns = [
        column
        for column in frame.columns
        if isinstance(column, str)
        and (column == "pearson" or column.startswith("precision_at_") or column.startswith("pearson_at_"))
        and pd.api.types.is_numeric_dtype(frame[column])
    ]
    if not metric_columns:
        raise ValueError("No recommender metric columns were found in the client results frame.")
    return metric_columns


def quantization_scale_suffix(scale: object) -> str:
    if scale is None:
        return "unknown"
    try:
        scale_int = int(scale)
    except (TypeError, ValueError):
        return sanitize_segment(scale)
    if scale_int <= 0:
        return sanitize_segment(scale_int)
    exponent = math.log2(scale_int)
    if float(exponent).is_integer():
        return f"2e{int(exponent)}"
    return sanitize_segment(scale_int)


def resolve_notebook_output_dir(
    repo_root: Path,
    run_id: str,
    selection_id: str,
    persona: str,
    model_key: str,
    aggregation_mode: str,
) -> Path:
    output_root_name = (
        "recommender_evaluation_outputs_ranksvm_secure"
        if aggregation_mode == "secure"
        else "recommender_evaluation_outputs_ranksvm_no_secure"
    )
    return (
        repo_root
        / "notebooks"
        / output_root_name
        / sanitize_segment(run_id)
        / sanitize_segment(selection_id)
        / sanitize_segment(persona)
        / sanitize_segment(model_key)
        / sanitize_segment(aggregation_mode)
    )


def resolve_comparison_output_dir(
    repo_root: Path,
    *,
    selection_id: str,
    persona: str,
    metric: str,
    quantization_scale: object,
) -> Path:
    scale_suffix = quantization_scale_suffix(quantization_scale)
    return (
        repo_root
        / "notebooks"
        / f"recommender_evaluation_comparison_outputs_{scale_suffix}"
        / sanitize_segment(selection_id)
        / sanitize_segment(persona)
        / sanitize_segment(metric)
    )


def save_dataframe(frame: pd.DataFrame, output_dir: Path, stem: str, *, index: bool = False) -> dict[str, str]:
    output_dir.mkdir(parents=True, exist_ok=True)
    csv_path = output_dir / f"{stem}.csv"
    html_path = output_dir / f"{stem}.html"
    frame.to_csv(csv_path, index=index)
    frame.to_html(html_path, index=index)
    return {"csv": str(csv_path), "html": str(html_path)}


def save_figure(fig: plt.Figure, output_dir: Path, stem: str, *, dpi: int = 200) -> str:
    output_dir.mkdir(parents=True, exist_ok=True)
    path = output_dir / f"{stem}.png"
    fig.savefig(path, dpi=dpi, bbox_inches="tight")
    return str(path)

# %%
REPO_ROOT = find_repo_root()
TRAIN_DIR = resolve_train_dir(
    REPO_ROOT,
    RUN_ID,
    SELECTION_ID,
    PERSONA,
    RECOMMENDER_MODEL_KEY,
    AGGREGATION_MODE_OVERRIDE,
)
ARTIFACTS = require_recommender_artifacts(TRAIN_DIR, RUN_ID)

training_metadata = load_json(ARTIFACTS["training_metadata"])
evaluation_summary = load_json(ARTIFACTS["evaluation_summary"])
run_info = parse_run_id(RUN_ID)

if training_metadata.get("status") != "completed":
    raise ValueError(f"Recommender training for {RUN_ID!r} is not marked completed: {training_metadata.get('status')!r}")

if evaluation_summary.get("status") not in {None, "completed", "evaluated"}:
    raise ValueError(f"Unexpected evaluation status for {RUN_ID!r}: {evaluation_summary.get('status')!r}")

if training_metadata.get("eval_instance_count", 0) <= 0:
    raise ValueError(f"Run {RUN_ID!r} has no held-out evaluation instances recorded in training_metadata.json")

AGGREGATION_MODE = aggregation_mode_label(training_metadata)
OUTPUT_DIR = resolve_notebook_output_dir(
    REPO_ROOT,
    RUN_ID,
    SELECTION_ID,
    PERSONA,
    RECOMMENDER_MODEL_KEY,
    AGGREGATION_MODE,
)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
NOTEBOOK_EXPORT_MANIFEST = {
    "run_id": RUN_ID,
    "selection_id": SELECTION_ID,
    "persona": PERSONA,
    "model_key": RECOMMENDER_MODEL_KEY,
    "aggregation_mode": AGGREGATION_MODE,
    "train_dir": str(TRAIN_DIR),
    "output_dir": str(OUTPUT_DIR),
    "saved_tables": {},
    "saved_figures": {},
}
save_json(OUTPUT_DIR / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)

OUTPUT_DIR
# Out:
# PosixPath('/gpfs/helios/home/kelemnegasi/fed-xai/fed-perso-xai/notebooks/recommender_evaluation_outputs_ranksvm_secure/federated-training-adult_income-20260425t192946577949_0000-logistic_regression-10clients-alpha1.0-seed42-dba03a50b07b/test__max-20__seed-42/lay/svm_rank_fedavg/secure')

# %%
display(build_title_block(run_info, training_metadata, SELECTION_ID, PERSONA))

aggregate = dict(evaluation_summary.get("aggregate", {}))
aggregate.pop("dataset_index", None)

run_overview = pd.DataFrame(
    {
        "run_id": [RUN_ID],
        "selection_id": [SELECTION_ID],
        "persona": [PERSONA],
        "model_key": [RECOMMENDER_MODEL_KEY],
        "aggregation_mode": [AGGREGATION_MODE],
        "alpha": [run_info.get("alpha")],
        "num_clients": [run_info.get("num_clients")],
        "top_k": [training_metadata.get("config", {}).get("top_k", [])],
        "rounds_completed": [training_metadata.get("rounds_completed")],
        "simulation_backend": [training_metadata.get("simulation_backend_actual")],
        "train_instances": [training_metadata.get("instance_count")],
        "test_instances": [training_metadata.get("eval_instance_count")],
        "train_candidates": [training_metadata.get("candidate_count")],
        "test_candidates": [training_metadata.get("eval_candidate_count")],
        "train_pairs_raw": [training_metadata.get("raw_pair_count")],
        "test_pairs_raw": [training_metadata.get("eval_raw_pair_count")],
        "train_pairs_augmented": [training_metadata.get("pair_count")],
        "test_pairs_augmented": [training_metadata.get("eval_pair_count")],
        "aggregate_pearson": [aggregate.get("pearson")],
        "aggregate_pearson_at_1": [aggregate.get("pearson_at_1")],
        "aggregate_pearson_at_3": [aggregate.get("pearson_at_3")],
        "aggregate_pearson_at_5": [aggregate.get("pearson_at_5")],
        "aggregate_pearson_at_8": [aggregate.get("pearson_at_8")],
        "aggregate_precision_at_1": [aggregate.get("precision_at_1")],
        "aggregate_precision_at_3": [aggregate.get("precision_at_3")],
        "aggregate_precision_at_5": [aggregate.get("precision_at_5")],
        "aggregate_precision_at_8": [aggregate.get("precision_at_8")],
    }
)

NOTEBOOK_EXPORT_MANIFEST["saved_tables"]["run_overview"] = save_dataframe(run_overview, OUTPUT_DIR, "run_overview")
save_json(OUTPUT_DIR / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)

run_overview
# Out:
# <h2 style='margin-bottom:4px'>Recommender evaluation: adult_income</h2><div style='color:#5f6368;margin-bottom:14px'><code>federated-training-adult_income-20260425t192946577949+0000-logistic_regression-10clients-alpha1.0-seed42-dba03a50b07b</code></div><div style='display:flex;gap:12px;flex-wrap:wrap'><div style='padding:14px 16px;border:1px solid #d0d7de;border-radius:12px;background:#f8fafc;min-width:180px'><div style='font-size:12px;text-transform:uppercase;color:#5f6368;letter-spacing:0.04em'>Aggregation</div><div style='font-size:26px;font-weight:700;margin-top:4px'>Secure</div></div><div style='padding:14px 16px;border:1px solid #d0d7de;border-radius:12px;background:#f8fafc;min-width:180px'><div style='font-size:12px;text-transform:uppercase;color:#5f6368;letter-spacing:0.04em'>Rounds</div><div style='font-size:26px;font-weight:700;margin-top:4px'>10</div></div><div style='padding:14px 16px;border:1px solid #d0d7de;border-radius:12px;background:#f8fafc;min-width:180px'><div sty
# ...

# %%
client_eval_df = pd.DataFrame(evaluation_summary.get("clients", []))
if client_eval_df.empty:
    raise ValueError(f"Run {RUN_ID!r} has no per-client evaluation results in evaluation_summary.json")

client_train_df = pd.DataFrame(training_metadata.get("clients", []))
if not client_train_df.empty:
    client_train_df = client_train_df.rename(
        columns={
            "candidate_count": "train_candidate_count",
            "instance_count": "train_instance_count",
            "raw_pair_count": "train_pair_count_raw",
            "augmented_pair_count": "train_pair_count_augmented",
        }
    )
    keep_columns = [
        "client_id",
        "train_candidate_count",
        "train_instance_count",
        "train_pair_count_raw",
        "train_pair_count_augmented",
    ]
    client_df = client_eval_df.merge(client_train_df[keep_columns], on="client_id", how="left")
else:
    client_df = client_eval_df.copy()

metric_columns = safe_metric_columns(client_df)
client_df["average_metric_score"] = client_df[metric_columns].mean(axis=1, skipna=True)
client_df["test_pairs_per_instance"] = client_df["pair_count"] / client_df["instance_count"]
client_df["test_candidates_per_instance"] = client_df["candidate_count"] / client_df["instance_count"]

NOTEBOOK_EXPORT_MANIFEST["saved_tables"]["client_metrics_full"] = save_dataframe(client_df, OUTPUT_DIR, "client_metrics_full")
save_json(OUTPUT_DIR / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)

client_df[
    [
        "client_id",
        "instance_count",
        "candidate_count",
        "pair_count",
        *metric_columns,
        "average_metric_score",
        "train_instance_count",
        "train_candidate_count",
        "train_pair_count_raw",
    ]
].sort_values("average_metric_score", ascending=False)
# Out:
#     client_id  instance_count  candidate_count  pair_count   pearson  pearson_at_1  pearson_at_3  pearson_at_5  precision_at_1  precision_at_3  precision_at_5  average_metric_score  \
# 0  client_000               4              210        5556  0.753134     -0.018898     -0.050128     -0.024489             0.0             0.0        0.131749              0.113053
# 5  client_005               4              203        5261  0.725007     -0.019293     -0.051232     -0.050488             0.0             0.0        0.139175              0.106167
# 2  client_002               4              188        4461  0.697160     -0.021072     -0.056104     -0.092429             0.0             0.0        0.000000              0.075365
# 8  client_008               4              167        3411  0.655087     -0.024480     -0.065473     -0.108366             0.0             0.0        0.000000              0.065253
# ...

# %%
aggregate_metric_frame = pd.DataFrame([summarize_metric(client_df, metric) for metric in metric_columns])
NOTEBOOK_EXPORT_MANIFEST["saved_tables"]["aggregate_metric_summary"] = save_dataframe(aggregate_metric_frame, OUTPUT_DIR, "aggregate_metric_summary")
save_json(OUTPUT_DIR / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)

aggregate_metric_frame
# Out:
#            metric      mean       std       min       max
# 0         pearson  0.416263  0.274909  0.020317  0.753134
# 1    pearson_at_1 -0.021340  0.002164 -0.024752 -0.018013
# 2    pearson_at_3 -0.056836  0.005947 -0.066236 -0.047689
# 3    pearson_at_5 -0.084518  0.025721 -0.109687 -0.024489
# 4  precision_at_1  0.000000  0.000000  0.000000  0.000000
# 5  precision_at_3  0.000000  0.000000  0.000000  0.000000
# 6  precision_at_5  0.027092  0.054210  0.000000  0.139175

# %%
top_clients = client_df.sort_values("average_metric_score", ascending=False).head(3)
bottom_clients = client_df.sort_values("average_metric_score", ascending=True).head(3)

NOTEBOOK_EXPORT_MANIFEST["saved_tables"]["top_clients"] = save_dataframe(top_clients, OUTPUT_DIR, "top_clients")
NOTEBOOK_EXPORT_MANIFEST["saved_tables"]["bottom_clients"] = save_dataframe(bottom_clients, OUTPUT_DIR, "bottom_clients")
save_json(OUTPUT_DIR / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)

print("Top clients by average held-out score")
display(top_clients[["client_id", *metric_columns, "average_metric_score", "candidate_count", "pair_count"]].round(4))

print("Lowest clients by average held-out score")
display(bottom_clients[["client_id", *metric_columns, "average_metric_score", "candidate_count", "pair_count"]].round(4))
# Out:
# Top clients by average held-out score
#     client_id  pearson  pearson_at_1  pearson_at_3  pearson_at_5  precision_at_1  precision_at_3  precision_at_5  average_metric_score  candidate_count  pair_count
# 0  client_000   0.7531       -0.0189       -0.0501       -0.0245             0.0             0.0          0.1317                0.1131              210        5556
# 5  client_005   0.7250       -0.0193       -0.0512       -0.0505             0.0             0.0          0.1392                0.1062              203        5261
# 2  client_002   0.6972       -0.0211       -0.0561       -0.0924             0.0             0.0          0.0000                0.0754              188        4461
# Lowest clients by average held-out score
#     client_id  pearson  pearson_at_1  pearson_at_3  pearson_at_5  precision_at_1  precision_at_3  precision_at_5  average_metric_score  candidate_count  pair_count
# ...

# %%
summary_columns = [
    "client_id",
    "instance_count",
    "candidate_count",
    "pair_count",
    *metric_columns,
    "average_metric_score",
    "test_candidates_per_instance",
    "test_pairs_per_instance",
    "train_instance_count",
    "train_candidate_count",
    "train_pair_count_raw",
]

client_report = client_df[summary_columns].sort_values("average_metric_score", ascending=False)
NOTEBOOK_EXPORT_MANIFEST["saved_tables"]["client_report"] = save_dataframe(client_report, OUTPUT_DIR, "client_report")
save_json(OUTPUT_DIR / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)

client_report.round(4)
# Out:
#     client_id  instance_count  candidate_count  pair_count  pearson  pearson_at_1  pearson_at_3  pearson_at_5  precision_at_1  precision_at_3  precision_at_5  average_metric_score  \
# 0  client_000               4              210        5556   0.7531       -0.0189       -0.0501       -0.0245             0.0             0.0          0.1317                0.1131
# 5  client_005               4              203        5261   0.7250       -0.0193       -0.0512       -0.0505             0.0             0.0          0.1392                0.1062
# 2  client_002               4              188        4461   0.6972       -0.0211       -0.0561       -0.0924             0.0             0.0          0.0000                0.0754
# 8  client_008               4              167        3411   0.6551       -0.0245       -0.0655       -0.1084             0.0             0.0          0.0000                0.0653
# ...

# %%
fig, axes = plt.subplots(1, len(metric_columns), figsize=(4.5 * len(metric_columns), 4), sharey=False)
if len(metric_columns) == 1:
    axes = [axes]

ordered = client_df.sort_values("average_metric_score", ascending=False)
for ax, metric in zip(axes, metric_columns):
    ax.bar(ordered["client_id"], ordered[metric], color="#2E86AB", alpha=0.9)
    ax.axhline(ordered[metric].mean(), color="#C73E1D", linestyle="--", linewidth=2, label="mean")
    ax.set_title(metric)
    ax.set_xlabel("client")
    ax.tick_params(axis="x", rotation=45)
    ax.legend()

plt.suptitle("Held-out test metrics by client", y=1.05, fontsize=14)
plt.tight_layout()
NOTEBOOK_EXPORT_MANIFEST["saved_figures"]["metrics_by_client"] = save_figure(fig, OUTPUT_DIR, "metrics_by_client")
save_json(OUTPUT_DIR / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)
plt.show()

# %%
def annotate_bars(ax, fmt="{:.3f}", rotation=0, fontsize=10):
    for container in ax.containers:
        labels = []
        for bar in container:
            height = bar.get_height()
            if pd.isna(height):
                labels.append("")
            else:
                labels.append(fmt.format(height))
        ax.bar_label(container, labels=labels, padding=3, rotation=rotation, fontsize=fontsize)


fig, axes = plt.subplots(1, 2, figsize=(12, 4))

aggregate_metric_frame.set_index("metric")[["mean", "std"]].plot(
    kind="bar",
    ax=axes[0],
    color=["#2E86AB", "#F18F01"],
    title="Mean and standard deviation across clients",
)
axes[0].tick_params(axis="x", rotation=45)
axes[0].set_ylabel("score")
axes[0].legend(loc="upper left", bbox_to_anchor=(1.02, 1.0))
annotate_bars(axes[0])

aggregate_metric_frame.set_index("metric")[["min", "max"]].plot(
    kind="bar",
    ax=axes[1],
    color=["#7B2CBF", "#2A9D8F"],
    title="Smallest and highest client score",
)
axes[1].tick_params(axis="x", rotation=45)
axes[1].set_ylabel("score")
axes[1].legend(loc="upper left", bbox_to_anchor=(1.0, 1.0))
annotate_bars(axes[1])

plt.tight_layout()
NOTEBOOK_EXPORT_MANIFEST["saved_figures"]["mean_metrics"] = save_figure(fig, OUTPUT_DIR, "mean_metrics")
save_json(OUTPUT_DIR / "export_manifest.json", NOTEBOOK_EXPORT_MANIFEST)
plt.show()

# %% [markdown]
# ## Notes
#
# - This notebook reads the **final post-training** recommender evaluation from `evaluation_summary.json`.
# - The reported metrics are for the **held-out test split** only.
# - If a `run_id` does not have completed recommender artifacts, the loading cell raises a clear error with the missing files.

# %% [markdown]
# ## Comparison
#
# This section compares exported recommender evaluation runs side by side. The registry below maps human-readable experiment labels to notebook output roots, so new variants such as `clustered_k_svm_secure` can be added later without rewriting the plotting logic.

# %%
COMPARISON_METRIC = "precision_at_5"

COMPARISON_ARTIFACT_CONFIGS = {
    "svm_secure": {
        "expected_model_key": "svm_rank_fedavg",
        "expected_aggregation_mode": "secure",
    },
    "svm_no_secure": {
        "expected_model_key": "svm_rank_fedavg",
        "expected_aggregation_mode": "plain",
    },
}

def _comparison_root_labels() -> list[str]:
    return list(COMPARISON_ARTIFACT_CONFIGS.keys())


def _extract_metric_row(frame: pd.DataFrame, metric: str) -> dict[str, float]:
    metric_row = frame.loc[frame["metric"] == metric]
    if metric_row.empty:
        return {"mean": np.nan, "std": np.nan}
    row = metric_row.iloc[0]
    return {
        "mean": float(row.get("mean", np.nan)),
        "std": float(row.get("std", np.nan)),
    }


def _secure_quantization_scale(training_metadata: dict) -> int | None:
    config = training_metadata.get("config", {})
    raw_value = config.get("secure_quantization_scale")
    if raw_value is None:
        return None
    try:
        return int(raw_value)
    except (TypeError, ValueError):
        return None


def _comparison_round_errors(training_history_path: Path) -> dict[str, float]:
    frame = pd.read_csv(training_history_path)
    errors: list[float] = []
    if "aggregation" in frame.columns:
        for raw_value in frame["aggregation"].dropna().tolist():
            try:
                payload = json.loads(raw_value)
            except (TypeError, json.JSONDecodeError):
                continue
            value = payload.get("max_abs_error")
            if isinstance(value, (int, float)):
                errors.append(float(value))
    elif "aggregation.max_abs_error" in frame.columns:
        errors = [
            float(value)
            for value in frame["aggregation.max_abs_error"].dropna().tolist()
            if pd.notna(value)
        ]
    if not errors:
        return {"max_abs_error_max": np.nan, "max_abs_error_mean": np.nan}
    return {
        "max_abs_error_max": float(max(errors)),
        "max_abs_error_mean": float(sum(errors) / len(errors)),
    }


def _comparison_model_difference(plain_model_path: Path, secure_model_path: Path) -> dict[str, float]:
    plain = np.load(plain_model_path, allow_pickle=True)
    secure = np.load(secure_model_path, allow_pickle=True)
    diff_vectors: list[np.ndarray] = []
    max_abs_values: list[float] = []
    for key in ("weights", "bias"):
        if key not in plain or key not in secure:
            continue
        plain_array = np.asarray(plain[key], dtype=np.float64)
        secure_array = np.asarray(secure[key], dtype=np.float64)
        diff = secure_array - plain_array
        diff_vectors.append(diff.reshape(-1))
        max_abs_values.append(float(np.max(np.abs(diff))))
    if not diff_vectors:
        return {"model_l2_diff": np.nan, "model_max_abs_diff": np.nan}
    flat_diff = np.concatenate(diff_vectors)
    return {
        "model_l2_diff": float(np.linalg.norm(flat_diff)),
        "model_max_abs_diff": float(max(max_abs_values)),
    }


def load_comparison_artifacts(config_label: str, config: dict[str, object]) -> list[dict[str, object]]:
    model_key = str(config["expected_model_key"])
    aggregation_mode = str(config["expected_aggregation_mode"])
    runs_root = REPO_ROOT / "federated" / "runs"
    entries: list[dict[str, object]] = []
    for run_dir in sorted(path for path in runs_root.iterdir() if path.is_dir()):
        train_dir = resolve_train_dir(
            REPO_ROOT,
            run_dir.name,
            SELECTION_ID,
            PERSONA,
            model_key,
            aggregation_mode,
        )
        try:
            artifacts = require_recommender_artifacts(train_dir, run_dir.name)
        except FileNotFoundError:
            continue
        training_metadata = load_json(artifacts["training_metadata"])
        if aggregation_mode_label(training_metadata) != aggregation_mode:
            continue
        evaluation_summary = load_json(artifacts["evaluation_summary"])
        client_df = build_client_metrics_frame(evaluation_summary)
        if client_df.empty or COMPARISON_METRIC not in client_df.columns:
            continue
        aggregate_df = build_aggregate_metric_summary(client_df)
        metric_stats = _extract_metric_row(aggregate_df, COMPARISON_METRIC)
        run_folder = sanitize_segment(run_dir.name)
        entries.append(
            {
                "config_label": config_label,
                "run_folder": run_folder,
                "run_id": run_dir.name,
                "selection_id": training_metadata.get("selection_id"),
                "persona": training_metadata.get("persona"),
                "model_key": model_key,
                "aggregation_mode": aggregation_mode,
                "train_dir": train_dir,
                "client_df": client_df,
                "aggregate_df": aggregate_df,
                "evaluation_summary": evaluation_summary,
                "training_metadata": training_metadata,
                "metric_mean": metric_stats["mean"],
                "metric_std": metric_stats["std"],
                "aggregate_metric": float(evaluation_summary.get("aggregate", {}).get(COMPARISON_METRIC, np.nan)),
                "secure_quantization_scale": _secure_quantization_scale(training_metadata),
            }
        )
    return entries


comparison_entries: list[dict[str, object]] = []
for comparison_label, comparison_config in COMPARISON_ARTIFACT_CONFIGS.items():
    comparison_entries.extend(load_comparison_artifacts(comparison_label, comparison_config))

if not comparison_entries:
    raise ValueError("No comparison artifacts were found under federated/runs for the configured model keys and aggregation modes.")

comparison_run_folders = sorted({entry["run_folder"] for entry in comparison_entries})
comparison_run_alias_map = {
    run_folder: f"run_id{index + 1}"
    for index, run_folder in enumerate(comparison_run_folders)
}
for entry in comparison_entries:
    entry["run_alias"] = comparison_run_alias_map[entry["run_folder"]]

secure_quantization_scales = sorted(
    {
        int(entry["secure_quantization_scale"])
        for entry in comparison_entries
        if entry.get("aggregation_mode") == "secure" and entry.get("secure_quantization_scale") is not None
    }
)
comparison_quantization_scale = secure_quantization_scales[0] if len(secure_quantization_scales) == 1 else None
comparison_scale_suffix = (
    quantization_scale_suffix(comparison_quantization_scale)
    if comparison_quantization_scale is not None
    else "mixed_scales"
)
COMPARISON_OUTPUT_DIR = resolve_comparison_output_dir(
    REPO_ROOT,
    selection_id=SELECTION_ID,
    persona=PERSONA,
    metric=COMPARISON_METRIC,
    quantization_scale=comparison_scale_suffix,
)
COMPARISON_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
COMPARISON_EXPORT_MANIFEST = {
    "selection_id": SELECTION_ID,
    "persona": PERSONA,
    "metric": COMPARISON_METRIC,
    "comparison_output_dir": str(COMPARISON_OUTPUT_DIR),
    "secure_quantization_scale": comparison_quantization_scale,
    "secure_quantization_scale_suffix": comparison_scale_suffix,
    "secure_quantization_scales_detected": secure_quantization_scales,
    "saved_tables": {},
    "saved_figures": {},
}

comparison_overview_rows: list[dict[str, object]] = []
for run_folder in comparison_run_folders:
    run_entries = [entry for entry in comparison_entries if entry["run_folder"] == run_folder]
    by_label = {entry["config_label"]: entry for entry in run_entries}
    representative = run_entries[0]
    row: dict[str, object] = {
        "run_alias": comparison_run_alias_map[run_folder],
        "run_folder": run_folder,
        "run_id": representative.get("run_id"),
        "selection_id": representative.get("selection_id"),
        "persona": representative.get("persona"),
    }
    for comparison_label in _comparison_root_labels():
        row[comparison_label] = comparison_label in by_label
    comparison_overview_rows.append(row)

comparison_overview = pd.DataFrame(comparison_overview_rows)
COMPARISON_EXPORT_MANIFEST["saved_tables"]["comparison_overview"] = save_dataframe(
    comparison_overview,
    COMPARISON_OUTPUT_DIR,
    "comparison_overview",
)
save_json(COMPARISON_OUTPUT_DIR / "comparison_export_manifest.json", COMPARISON_EXPORT_MANIFEST)
comparison_overview

comparison_colors = {
    label: color
    for label, color in zip(
        _comparison_root_labels(),
        ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"],
    )
}

for run_folder in comparison_run_folders:
    run_entries = [entry for entry in comparison_entries if entry["run_folder"] == run_folder]
    run_entries = sorted(run_entries, key=lambda entry: _comparison_root_labels().index(entry["config_label"]))
    run_alias = comparison_run_alias_map[run_folder]
    display(
        HTML(
            f"<h3 style='margin-top:20px'>{run_alias}</h3>"
            f"<div style='margin-bottom:10px'><code>{run_entries[0]['run_id']}</code></div>"
        )
    )

    client_metric_wide: pd.DataFrame | None = None
    summary_rows: list[dict[str, object]] = []
    for entry in run_entries:
        label = entry["config_label"]
        client_slice = entry["client_df"][["client_id", COMPARISON_METRIC]].copy()
        client_slice = client_slice.rename(columns={COMPARISON_METRIC: label})
        if client_metric_wide is None:
            client_metric_wide = client_slice
        else:
            client_metric_wide = client_metric_wide.merge(client_slice, on="client_id", how="outer")

        summary_rows.append(
            {
                "config": label,
                "aggregate": entry["aggregate_metric"],
                "mean": entry["metric_mean"],
                "std": entry["metric_std"],
                "model_key": entry["model_key"],
                "aggregation_mode": entry["aggregation_mode"],
                "train_dir": str(entry["train_dir"]),
                "secure_quantization_scale": entry.get("secure_quantization_scale"),
            }
        )

    if client_metric_wide is None:
        continue

    client_metric_wide = client_metric_wide.sort_values("client_id").reset_index(drop=True)
    summary_frame = pd.DataFrame(summary_rows)
    display(summary_frame.round(4))

    secure_entry = next((entry for entry in run_entries if entry.get("aggregation_mode") == "secure"), None)
    plain_entry = next((entry for entry in run_entries if entry.get("aggregation_mode") == "plain"), None)
    diagnostics_payload: dict[str, object] | None = None
    if secure_entry is not None and plain_entry is not None:
        secure_errors = _comparison_round_errors(Path(str(secure_entry["train_dir"])) / "training_history.csv")
        model_difference = _comparison_model_difference(
            Path(str(plain_entry["train_dir"])) / "model" / "global_recommender.npz",
            Path(str(secure_entry["train_dir"])) / "model" / "global_recommender.npz",
        )
        secure_eval = secure_entry["evaluation_summary"]
        plain_eval = plain_entry["evaluation_summary"]
        diagnostics_payload = {
            "run_alias": run_alias,
            "run_id": secure_entry.get("run_id", plain_entry.get("run_id")),
            "selection_id": SELECTION_ID,
            "persona": PERSONA,
            "comparison_metric": COMPARISON_METRIC,
            "secure_quantization_scale": secure_entry.get("secure_quantization_scale"),
            "precision_at_5_plain": float(plain_eval.get("aggregate", {}).get("precision_at_5", np.nan)),
            "precision_at_5_secure": float(secure_eval.get("aggregate", {}).get("precision_at_5", np.nan)),
            "precision_at_5_delta": float(
                secure_eval.get("aggregate", {}).get("precision_at_5", np.nan)
                - plain_eval.get("aggregate", {}).get("precision_at_5", np.nan)
            ),
            "pearson_plain": float(plain_eval.get("aggregate", {}).get("pearson", np.nan)),
            "pearson_secure": float(secure_eval.get("aggregate", {}).get("pearson", np.nan)),
            "pearson_delta": float(
                secure_eval.get("aggregate", {}).get("pearson", np.nan)
                - plain_eval.get("aggregate", {}).get("pearson", np.nan)
            ),
            **secure_errors,
            **model_difference,
        }

    run_stem = sanitize_segment(run_alias)
    COMPARISON_EXPORT_MANIFEST["saved_tables"][f"{run_stem}_client_{COMPARISON_METRIC}"] = save_dataframe(
        client_metric_wide,
        COMPARISON_OUTPUT_DIR,
        f"{run_stem}_client_{COMPARISON_METRIC}",
    )
    COMPARISON_EXPORT_MANIFEST["saved_tables"][f"{run_stem}_summary_{COMPARISON_METRIC}"] = save_dataframe(
        summary_frame,
        COMPARISON_OUTPUT_DIR,
        f"{run_stem}_summary_{COMPARISON_METRIC}",
    )
    if diagnostics_payload is not None:
        diagnostics_path = save_json(
            COMPARISON_OUTPUT_DIR / f"{run_stem}_diagnostics.json",
            diagnostics_payload,
        )
        COMPARISON_EXPORT_MANIFEST.setdefault("saved_diagnostics", {})[run_stem] = str(diagnostics_path)

    ordered_labels = [entry["config_label"] for entry in run_entries]
    plot_colors = [comparison_colors.get(label, "#333333") for label in ordered_labels]

    fig, axes = plt.subplots(1, 2, figsize=(18, 5))

    client_metric_wide.set_index("client_id")[ordered_labels].plot(
        kind="bar",
        ax=axes[0],
        color=plot_colors,
        width=0.85,
    )
    axes[0].set_title(f"{run_alias}: client {COMPARISON_METRIC}")
    axes[0].set_xlabel("client_id")
    axes[0].set_ylabel(COMPARISON_METRIC)
    axes[0].tick_params(axis="x", rotation=45)
    axes[0].legend(title="training_type", loc="upper left", bbox_to_anchor=(1.01, 1.0))

    aggregate_positions = np.arange(len(summary_frame))
    bars = axes[1].bar(
        aggregate_positions,
        summary_frame["aggregate"],
        color=plot_colors,
        alpha=0.9,
    )
    axes[1].set_xticks(aggregate_positions)
    axes[1].set_xticklabels(summary_frame["config"], rotation=20, ha="right")
    axes[1].set_ylabel(COMPARISON_METRIC)
    axes[1].set_title(f"{run_alias}: aggregate {COMPARISON_METRIC}")
    for bar, aggregate_value in zip(bars, summary_frame["aggregate"], strict=True):
        if pd.isna(aggregate_value):
            continue
        axes[1].text(
            bar.get_x() + bar.get_width() / 2,
            aggregate_value + 0.02,
            f"{aggregate_value:.3f}",
            ha="center",
            va="bottom",
            fontsize=9,
        )

    plt.tight_layout()
    COMPARISON_EXPORT_MANIFEST["saved_figures"][f"{run_stem}_{COMPARISON_METRIC}"] = save_figure(
        fig,
        COMPARISON_OUTPUT_DIR,
        f"{run_stem}_{COMPARISON_METRIC}",
    )
    save_json(COMPARISON_OUTPUT_DIR / "comparison_export_manifest.json", COMPARISON_EXPORT_MANIFEST)
    plt.show()

COMPARISON_EXPORT_MANIFEST
# Out:
# <h3 style='margin-top:20px'>run_id1</h3><div style='margin-bottom:10px'><code>federated-training-adult_income-20260425t192946577949+0000-logistic_regression-10clients-alpha1.0-seed42-dba03a50b07b</code></div>
#           config  aggregate    mean     std        model_key aggregation_mode  \
# 0     svm_secure     0.0323  0.0271  0.0542  svm_rank_fedavg           secure
# 1  svm_no_secure     0.6426  0.6481  0.1171  svm_rank_fedavg            plain
#
#                                                                                                                  train_dir  secure_quantization_scale
# 0  /gpfs/helios/home/kelemnegasi/fed-xai/fed-perso-xai/federated/runs/federated-training-adult_income-20260425t19294657...                   16777216
# 1  /gpfs/helios/home/kelemnegasi/fed-xai/fed-perso-xai/federated/runs/federated-training-adult_income-20260425t19294657...                   16777216
# ...

# %%
COMPARISON_METRICS = ["precision_at_1", "precision_at_3", "precision_at_5", "precision_at_8", "pearson", "pearson_at_1", "pearson_at_3", "pearson_at_5", "pearson_at_8"]

if "comparison_entries" not in globals() or not comparison_entries:
    raise ValueError(
        "Run the Comparison section cell first so comparison_entries and COMPARISON_OUTPUT_DIR are available."
    )

available_comparison_metrics = [
    metric
    for metric in COMPARISON_METRICS
    if any(metric in entry["client_df"].columns for entry in comparison_entries)
]
if not available_comparison_metrics:
    raise ValueError("None of the requested comparison metrics are available in the loaded comparison artifacts.")

missing_comparison_metrics = [
    metric for metric in COMPARISON_METRICS if metric not in available_comparison_metrics
]
if missing_comparison_metrics:
    display(
        HTML(
            "<div style='padding:10px 12px;border:1px solid #f0c36d;border-radius:10px;background:#fff8e1'>"
            "Skipped unavailable metrics: <code>"
            + ", ".join(missing_comparison_metrics)
            + "</code>. Older artifacts may only expose the global <code>pearson</code> metric until they are regenerated."
            "</div>"
        )
    )

multi_metric_overview_rows: list[dict[str, object]] = []
for run_folder in comparison_run_folders:
    run_entries = [entry for entry in comparison_entries if entry["run_folder"] == run_folder]
    by_label = {entry["config_label"]: entry for entry in run_entries}
    representative = run_entries[0]
    row: dict[str, object] = {
        "run_alias": comparison_run_alias_map[run_folder],
        "run_folder": run_folder,
        "run_id": representative.get("run_id"),
    }
    for comparison_label in _comparison_root_labels():
        entry = by_label.get(comparison_label)
        aggregate_payload = entry.get("evaluation_summary", {}).get("aggregate", {}) if entry is not None else {}
        for metric in available_comparison_metrics:
            row[f"{comparison_label}__{metric}"] = float(aggregate_payload.get(metric, np.nan))
    secure_entry = by_label.get("svm_secure")
    plain_entry = by_label.get("svm_no_secure")
    if secure_entry is not None and plain_entry is not None:
        secure_aggregate = secure_entry["evaluation_summary"].get("aggregate", {})
        plain_aggregate = plain_entry["evaluation_summary"].get("aggregate", {})
        for metric in available_comparison_metrics:
            row[f"delta__{metric}"] = float(
                secure_aggregate.get(metric, np.nan) - plain_aggregate.get(metric, np.nan)
            )
    multi_metric_overview_rows.append(row)

multi_metric_overview = pd.DataFrame(multi_metric_overview_rows)
COMPARISON_EXPORT_MANIFEST["saved_tables"]["comparison_multi_metric_overview"] = save_dataframe(
    multi_metric_overview,
    COMPARISON_OUTPUT_DIR,
    "comparison_multi_metric_overview",
)
save_json(COMPARISON_OUTPUT_DIR / "comparison_export_manifest.json", COMPARISON_EXPORT_MANIFEST)
multi_metric_overview.round(4)

for run_folder in comparison_run_folders:
    run_entries = [entry for entry in comparison_entries if entry["run_folder"] == run_folder]
    run_entries = sorted(run_entries, key=lambda entry: _comparison_root_labels().index(entry["config_label"]))
    run_alias = comparison_run_alias_map[run_folder]

    summary_rows: list[dict[str, object]] = []
    for entry in run_entries:
        aggregate_payload = entry["evaluation_summary"].get("aggregate", {})
        row = {
            "config": entry["config_label"],
            "aggregation_mode": entry["aggregation_mode"],
            "train_dir": str(entry["train_dir"]),
        }
        for metric in available_comparison_metrics:
            row[metric] = float(aggregate_payload.get(metric, np.nan))
        summary_rows.append(row)
    summary_frame = pd.DataFrame(summary_rows)

    secure_row = summary_frame.loc[summary_frame["aggregation_mode"] == "secure"]
    plain_row = summary_frame.loc[summary_frame["aggregation_mode"] == "plain"]
    delta_frame = pd.DataFrame()
    if not secure_row.empty and not plain_row.empty:
        delta_frame = pd.DataFrame(
            [
                {
                    "metric": metric,
                    "secure": float(secure_row.iloc[0][metric]),
                    "plain": float(plain_row.iloc[0][metric]),
                    "delta": float(secure_row.iloc[0][metric] - plain_row.iloc[0][metric]),
                }
                for metric in available_comparison_metrics
            ]
        )

    display(
        HTML(
            f"<h3 style='margin-top:20px'>{run_alias}: multi-metric aggregate comparison</h3>"
            f"<div style='margin-bottom:10px'><code>{run_entries[0]['run_id']}</code></div>"
        )
    )
    display(summary_frame.round(4))
    if not delta_frame.empty:
        display(delta_frame.round(4))

    run_stem = sanitize_segment(run_alias)
    COMPARISON_EXPORT_MANIFEST["saved_tables"][f"{run_stem}_multi_metric_summary"] = save_dataframe(
        summary_frame,
        COMPARISON_OUTPUT_DIR,
        f"{run_stem}_multi_metric_summary",
    )
    if not delta_frame.empty:
        COMPARISON_EXPORT_MANIFEST["saved_tables"][f"{run_stem}_multi_metric_delta"] = save_dataframe(
            delta_frame,
            COMPARISON_OUTPUT_DIR,
            f"{run_stem}_multi_metric_delta",
        )

    n_metrics = len(available_comparison_metrics)
    ncols = 2
    nrows = math.ceil(n_metrics / ncols)
    fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 4.5 * nrows), squeeze=False)
    flat_axes = list(axes.flat)
    plot_colors = [comparison_colors.get(config, "#333333") for config in summary_frame["config"]]
    for ax, metric in zip(flat_axes, available_comparison_metrics, strict=False):
        bars = ax.bar(summary_frame["config"], summary_frame[metric], color=plot_colors, alpha=0.9)
        ax.set_title(metric)
        ax.set_ylabel("score")
        ax.tick_params(axis="x", rotation=20)
        for bar, value in zip(bars, summary_frame[metric], strict=True):
            if pd.isna(value):
                continue
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                value,
                f"{value:.3f}",
                ha="center",
                va="bottom",
                fontsize=9,
            )
    for ax in flat_axes[n_metrics:]:
        ax.axis("off")
    plt.tight_layout()
    COMPARISON_EXPORT_MANIFEST["saved_figures"][f"{run_stem}_multi_metric_comparison"] = save_figure(
        fig,
        COMPARISON_OUTPUT_DIR,
        f"{run_stem}_multi_metric_comparison",
    )
    save_json(COMPARISON_OUTPUT_DIR / "comparison_export_manifest.json", COMPARISON_EXPORT_MANIFEST)
    plt.show()
# Out:
# <div style='padding:10px 12px;border:1px solid #f0c36d;border-radius:10px;background:#fff8e1'>Skipped unavailable metrics: <code>precision_at_8, pearson_at_8</code>. Older artifacts may only expose the global <code>pearson</code> metric until they are regenerated.</div>
# <h3 style='margin-top:20px'>run_id1: multi-metric aggregate comparison</h3><div style='margin-bottom:10px'><code>federated-training-adult_income-20260425t192946577949+0000-logistic_regression-10clients-alpha1.0-seed42-dba03a50b07b</code></div>
#           config aggregation_mode                                                                                                                train_dir  precision_at_1  precision_at_3  \
# 0     svm_secure           secure  /gpfs/helios/home/kelemnegasi/fed-xai/fed-perso-xai/federated/runs/federated-training-adult_income-20260425t19294657...          0.0000           0.000
# ...
